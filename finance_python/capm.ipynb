# %%
import numpy as np
import pandas as pd
import tushare as ts
import seaborn as sns
import matplotlib.pyplot as plt
from tsdata import get_data, get_data_old
plt.style.use('dark_background')

# %%
start = "2014-01-01"
end = "2019-01-01"
symbols = ["600104", "510300"]

price = get_data_old(symbols, start, end)
price
# Out:
#             600104  510300
# 2014-01-02  10.278   2.368
# 2014-01-03   9.982   2.342
# 2014-01-06   9.677   2.286
# 2014-01-07   9.751   2.287
# 2014-01-08   9.944   2.285
# 2014-01-09   9.692   2.271
# 2014-01-10   9.692   2.255
# 2014-01-13   9.655   2.239
# 2014-01-14   9.729   2.254
# 2014-01-15   9.796   2.254
# 2014-01-16   9.722   2.255
# 2014-01-17   9.373   2.223
# 2014-01-20   9.262   2.212
# 2014-01-21   9.410   2.182
# 2014-01-22   9.714   2.242
# 2014-01-23   9.700   2.230
# 2014-01-24   9.781   2.242
# 2014-01-27   9.700   2.213
# 2014-01-28   9.714   2.215
# 2014-01-29   9.714   2.222
# 2014-01-30   9.633   2.191
# 2014-02-07   9.610   2.205
# 2014-02-10  10.004   2.269
# 2014-02-11  10.034   2.280
# 2014-02-12   9.930   2.284
# 2014-02-13   9.952   2.278
# 2014-02-14  10.019   2.286
# 2014-02-17  10.167   2.302
# 2014-02-18   9.989   2.275
# 2014-02-19  10.108   2.305
# ...            ...     ...
# 2018-11-19  25.750   3.348
# 2018-11-20  25.680   3.275
# ...

# %%
returns = np.log(price / price.shift(1))
cov = returns.cov() * 250
cov
# Out:
#           600104    510300
# 600104  0.107227  0.056561
# 510300  0.056561  0.070293

# %%
cov_with_market = cov.iloc[0, 1]
market_var = cov.iloc[1, 1]
cov_with_market, market_var
# Out:
# (0.05656102348374051, 0.07029300419198044)

# %%
market_var_vef = returns['510300'].var() * 250
market_var_vef
# Out:
# 0.0702930041919803

# %%
beta = cov_with_market / market_var
beta
# Out:
# 0.8046465524401847
